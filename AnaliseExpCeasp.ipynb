# %% [markdown]
# ## Análise Exploratória CEAPS
#
# Este projeto tem por objetivo analisar as variáveis dos dados públicos de Cota para Exercício da Atividade Parlamentar dos Senadores.
#
# O foco da análise é extrair informações sobre as despesase os valores reembolsados pelo Senadores em 2022 e gerar insight através de gráficos dinâmicos com a biblioteca plotly.
#
# - Download do dataset CEAPS: https://www12.senado.leg.br/dados-abertos/conjuntos?portal=Administrativo&grupo=senadores
# - Data Wragling;
# - Data Visualization;
# - Deploy Streamlit.

# %%
# Importação das bibliotecas
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import streamlit as st

# %%
# Leitura do dataset CEAPS
df = pd.read_csv('despesa_ceaps_2022 (1).csv', sep=';')
display(df.head(5))
# Out:
#   ULTIMA ATUALIZACAO 17/07/2023 02:01    Unnamed: 2  \
# 0                ANO              MES       SENADOR
# 1               2022                1  ACIR GURGACZ
# 2               2022                1  ACIR GURGACZ
# 3               2022                1  ACIR GURGACZ
# 4               2022                1  ACIR GURGACZ
#
#                                           Unnamed: 3          Unnamed: 4  \
# 0                                       TIPO_DESPESA            CNPJ_CPF
# 1  Aluguel de imóveis para escritório político, c...      004.948.028-63
# 2                Divulgação da atividade parlamentar  26.320.603/0001-64
# 3                Divulgação da atividade parlamentar  13.659.201/0001-47
# 4                Divulgação da atividade parlamentar  23.652.846/0001-01
#
#                           Unnamed: 5         Unnamed: 6  Unnamed: 7  \
# 0                         FORNECEDOR          DOCUMENTO        DATA
# 1      GILBERTO PISELO DO NASCIMENTO             001/22  03/01/2022
# 2                      INFORMANAHORA  000000000000310/A  04/01/2022
# 3    LINHA PURPURA FOTO E VIDEO LTDA                107  14/01/2022
# 4  ROBERTO GUTIERREZ DA ROCHA M.E.I.                187  18/01/2022
#
#                                           Unnamed: 8         Unnamed: 9  \
# 0                                       DETALHAMENTO  VALOR_REEMBOLSADO
# 1  Despesa com pagamento de aluguel de imóvel par...               6000
# 2  Despesa com divulgação da atividade parlamenta...               1500
# 3  Despesa com produção de texto e edição de víde...               6000
# 4                Divulgação da atividade parlamentar               1000
#
#      Unnamed: 10
# 0  COD_DOCUMENTO
# 1        2173614
# 2        2173615
# 3        2173616
# 4        2173618

# %% [markdown]
# ### Data Wrangling
#
# Nessa etapa realizamos a limpeza dos dados.

# %%
# Definir a primeira linha como cabeçalho
df.columns = df.iloc[0]

# Excluir a primeira linha duplicada
df = df[1:]

# %%
df.sample(2)
# Out:
# 0       ANO MES         SENADOR  \
# 10801  2022   1  MARCELO CASTRO
# 11215  2022  11   MARCOS DO VAL
#
# 0                                           TIPO_DESPESA            CNPJ_CPF  \
# 10801  Locomoção, hospedagem, alimentação, combustíve...  07.321.071/0001-35
# 11215  Locomoção, hospedagem, alimentação, combustíve...  27.419.142/0001-44
#
# 0                                           FORNECEDOR DOCUMENTO        DATA  \
# 10801                           LUAUTO RENT A CAR LTDA       486  16/03/2022
# 11215  POSTO IATE LTDA- 42838- VENDA / COMBUST.LUBRIF.     19252  21/11/2022
#
# 0                                           DETALHAMENTO VALOR_REEMBOLSADO  \
# 10801  Despesa de locação de veículo utilizado na ati...              7000
# 11215                                                NaN            216,92
#
# 0     COD_DOCUMENTO
# 10801       2176986
# 11215       2190560

# %%
# Verificar a quantidade de linhas e colunas
df.shape
# Out:
# (16782, 11)

# %%
# Corrigir os tipos de dados das variáveis
df.dtypes
# Out:
# 0
# ANO                  object
# MES                  object
# SENADOR              object
# TIPO_DESPESA         object
# CNPJ_CPF             object
# FORNECEDOR           object
# DOCUMENTO            object
# DATA                 object
# DETALHAMENTO         object
# VALOR_REEMBOLSADO    object
# COD_DOCUMENTO        object
# dtype: object

# %%
# Alteração do cabeçalho
var_col = [nome.capitalize() for nome in df.columns]
df.columns = var_col

# %%
# Capitalizando as variáveis para padronização
var_senador = [nome.capitalize() for nome in df['Senador']]
df['Senador'] = var_senador

var_fornecedor = [nome.capitalize() for nome in df['Fornecedor']]
df['Fornecedor'] = var_fornecedor

display(df.head(5))
# Out:
#     Ano Mes       Senador                                       Tipo_despesa  \
# 1  2022   1  Acir gurgacz  Aluguel de imóveis para escritório político, c...
# 2  2022   1  Acir gurgacz                Divulgação da atividade parlamentar
# 3  2022   1  Acir gurgacz                Divulgação da atividade parlamentar
# 4  2022   1  Acir gurgacz                Divulgação da atividade parlamentar
# 5  2022   1  Acir gurgacz                Divulgação da atividade parlamentar
#
#              Cnpj_cpf                                         Fornecedor  \
# 1      004.948.028-63                      Gilberto piselo do nascimento
# 2  26.320.603/0001-64                                      Informanahora
# 3  13.659.201/0001-47                    Linha purpura foto e video ltda
# 4  23.652.846/0001-01                  Roberto gutierrez da rocha m.e.i.
# 5  08.941.827/0001-01  Rondonia dinâmica com. e serv. de informática ...
#
#            Documento        Data  \
# 1             001/22  03/01/2022
# 2  000000000000310/A  04/01/2022
# 3                107  14/01/2022
# 4                187  18/01/2022
# 5  000000000001772/A  17/01/2022
#
#                                         Detalhamento Valor_reembolsado  \
# 1  Despesa com pagamento de aluguel de imóvel par...              6000
# 2  Despesa com divulgação da atividade parlamenta...              1500
# 3  Despesa com produção de texto e edição de víde...              6000
# 4                Divulgação da atividade parlamentar              1000
# 5                Divulgação da atividade parlamentar              2000
#
#   Cod_documento
# 1       2173614
# 2       2173615
# 3       2173616
# 4       2173618
# 5       2173617

# %%
# Conversão da variável para data
df['Data'] = pd.to_datetime(df['Data'])

# %%
# Alteração do separador ',' para '.' e transformação para Float
df['Valor_reembolsado'] = df['Valor_reembolsado'].str.replace(',','.')
df['Valor_reembolsado'] = df['Valor_reembolsado'].astype(float)

# %%
# Nova verificação dos tipos de dados
df.dtypes
# Out:
# Ano                          object
# Mes                          object
# Senador                      object
# Tipo_despesa                 object
# Cnpj_cpf                     object
# Fornecedor                   object
# Documento                    object
# Data                 datetime64[ns]
# Detalhamento                 object
# Valor_reembolsado           float64
# Cod_documento                object
# dtype: object

# %%
# Verificação das células vazias
df.isnull().sum()
# Out:
# Ano                     0
# Mes                     0
# Senador                 0
# Tipo_despesa            0
# Cnpj_cpf                0
# Fornecedor              0
# Documento             934
# Data                    0
# Detalhamento         7720
# Valor_reembolsado       0
# Cod_documento           0
# dtype: int64

# %%
# Verificação das observações vazias
df[df['Detalhamento'].isna()].head(5)
# Out:
#       Ano Mes            Senador  \
# 121  2022   1  Alessandro vieira
# 122  2022   1  Alessandro vieira
# 123  2022   1  Alessandro vieira
# 124  2022   1  Alessandro vieira
# 125  2022   1  Alessandro vieira
#
#                                           Tipo_despesa            Cnpj_cpf  \
# 121  Aluguel de imóveis para escritório político, c...  28.839.939/0001-63
# 122  Aluguel de imóveis para escritório político, c...  06.028.059/0001-74
# 123  Aluguel de imóveis para escritório político, c...  40.432.544/0107-03
# 124  Aluguel de imóveis para escritório político, c...  13.017.462/0001-63
# 125  Aquisição de material de consumo para uso no e...  11.088.468/0001-04
#
#                                             Fornecedor    Documento  \
# 121  Casa design servicos de apoio administrativo ltda         1253
# 122                    Casa shopping desing ltda - epp         1872
# 123                                    Claro s.a / net  2,20191E+12
# 124                                           Energisa   42.551.180
# 125                              Kaflex comercial ltda            1
#
#           Data Detalhamento  Valor_reembolsado Cod_documento
# 121 2022-04-01          NaN             500.00       2175348
# 122 2022-10-02          NaN            3300.00       2175347
# 123 2022-01-01          NaN             235.96       2174131
# 124 2022-01-13          NaN             455.96       2174169
# 125 2022-02-23          NaN             800.00       2175349

# %%
# Excluindo colunas não utilizáveis
df = df.drop(columns=['Documento'], axis=1)
df = df.drop(columns=['Detalhamento'], axis=1)

# %% [markdown]
# Não manteremos as variáveis 'Documento' e 'Detalhamento', ambas não serão influenciadas na análise-alvo.

# %%
# Analisando a variável "Tipo_despesa"
df.head(5)
# Out:
#     Ano Mes       Senador                                       Tipo_despesa  \
# 1  2022   1  Acir gurgacz  Aluguel de imóveis para escritório político, c...
# 2  2022   1  Acir gurgacz                Divulgação da atividade parlamentar
# 3  2022   1  Acir gurgacz                Divulgação da atividade parlamentar
# 4  2022   1  Acir gurgacz                Divulgação da atividade parlamentar
# 5  2022   1  Acir gurgacz                Divulgação da atividade parlamentar
#
#              Cnpj_cpf                                         Fornecedor  \
# 1      004.948.028-63                      Gilberto piselo do nascimento
# 2  26.320.603/0001-64                                      Informanahora
# 3  13.659.201/0001-47                    Linha purpura foto e video ltda
# 4  23.652.846/0001-01                  Roberto gutierrez da rocha m.e.i.
# 5  08.941.827/0001-01  Rondonia dinâmica com. e serv. de informática ...
#
#         Data  Valor_reembolsado Cod_documento
# 1 2022-03-01             6000.0       2173614
# 2 2022-04-01             1500.0       2173615
# 3 2022-01-14             6000.0       2173616
# 4 2022-01-18             1000.0       2173618
# 5 2022-01-17             2000.0       2173617

# %%
# Verificando se há valores únicos e categorizados
df.Tipo_despesa.unique()
# Out:
# array(['Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles.',
#        'Divulgação da atividade parlamentar',
#        'Passagens aéreas, aquáticas e terrestres nacionais',
#        'Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar',
#        'Locomoção, hospedagem, alimentação, combustíveis e lubrificantes',
#        'Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos. ',
#        'Serviços de Segurança Privada'], dtype=object)

# %%
# Categorizando de forma resumida as informações
cat_despesa = {'Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles.': 'Cat01',
    'Divulgação da atividade parlamentar': 'Cat02',
    'Passagens aéreas, aquáticas e terrestres nacionais': 'Cat03',
    'Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar': 'Cat04',
    'Locomoção, hospedagem, alimentação, combustíveis e lubrificantes':'Cat05',
    'Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos. ': 'Cat06',
    'Serviços de Segurança Privada': 'Cat07'}

# %%
# Categorizando o tipo de despesa
df['categ_despesa'] = df['Tipo_despesa'].map(cat_despesa)

# %%
# Mes
# Categoria de despesa
# Gasto total
# diaMes

# %%
df['dia_mes'] = pd.to_datetime(df['Data']).dt.strftime('%d%m')
df.head(2)
# Out:
#     Ano Mes       Senador                                       Tipo_despesa  \
# 1  2022   1  Acir gurgacz  Aluguel de imóveis para escritório político, c...
# 2  2022   1  Acir gurgacz                Divulgação da atividade parlamentar
#
#              Cnpj_cpf                     Fornecedor       Data  \
# 1      004.948.028-63  Gilberto piselo do nascimento 2022-03-01
# 2  26.320.603/0001-64                  Informanahora 2022-04-01
#
#    Valor_reembolsado Cod_documento categ_despesa dia_mes
# 1             6000.0       2173614         Cat01    0103
# 2             1500.0       2173615         Cat02    0104

# %%
# Criando colunas auxiliares de datas
df['Mes'] = df['Data'].dt.month
df['Dia'] = df['Data'].dt.day

# %%
# Alterando a posição
df.insert(2, 'Dia', df.pop('Dia'))

# %%
df.head(2)
# Out:
#     Ano  Mes  Dia       Senador  \
# 1  2022    3    1  Acir gurgacz
# 2  2022    4    1  Acir gurgacz
#
#                                         Tipo_despesa            Cnpj_cpf  \
# 1  Aluguel de imóveis para escritório político, c...      004.948.028-63
# 2                Divulgação da atividade parlamentar  26.320.603/0001-64
#
#                       Fornecedor       Data  Valor_reembolsado Cod_documento  \
# 1  Gilberto piselo do nascimento 2022-03-01             6000.0       2173614
# 2                  Informanahora 2022-04-01             1500.0       2173615
#
#   categ_despesa dia_mes
# 1         Cat01    0103
# 2         Cat02    0104

# %%
df.to_csv('Clean_despesas_CEASP.csv', sep=';')
